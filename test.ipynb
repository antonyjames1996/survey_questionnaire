# %%
import pandas as pd
import os
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
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

# %%
api_key = os.getenv("OPENROUTER_KEY") 
print(api_key)
# Out:
# None
